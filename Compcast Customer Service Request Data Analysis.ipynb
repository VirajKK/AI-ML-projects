# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')
data.head(10)
# Out:
# C:\Users\91983\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (48,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01-01-16 1:26   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01-01-16 4:51   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01-01-16 7:43   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01-01-16 3:24   NYPD
# 5    32306554  12/31/2015 11:56:30 PM  01-01-16 1:50   NYPD
# 6    32306559  12/31/2015 11:55:32 PM  01-01-16 1:53   NYPD
# 7    32307009  12/31/2015 11:54:05 PM  01-01-16 1:42   NYPD
# 8    32308581  12/31/2015 11:53:58 PM  01-01-16 8:27   NYPD
# 9    32308391  12/31/2015 11:53:58 PM  01-01-16 1:17   NYPD
#
# ...

# %%
data.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
data['Created Date'] = pd.to_datetime(data['Created Date'])
data['Closed Date'] = pd.to_datetime(data['Closed Date'])
for i in range(len(data)):
    data['Request_Closing_Time'][i] = pd.Timedelta((data['Closed Date'][i] - data['Created Date'][i]),unit='Hours')
# Out:
# <ipython-input-66-6f2ec66874c7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Request_Closing_Time'][i] = pd.Timedelta((data['Closed Date'][i] - data['Created Date'][i]),unit='Hours')

# %%
data
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 0         32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1         32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2         32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3         32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4         32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
# ...            ...                 ...                 ...    ...
# 300693    30281872 2015-03-29 00:33:41                 NaT   NYPD
# 300694    30281230 2015-03-29 00:33:28 2015-03-29 02:33:59   NYPD
# 300695    30283424 2015-03-29 00:33:03 2015-03-29 03:40:20   NYPD
# 300696    30280004 2015-03-29 00:33:02 2015-03-29 04:38:35   NYPD
# 300697    30281825 2015-03-29 00:33:01 2015-03-29 04:41:50   NYPD
#
#                             Agency Name           Complaint Type  \
# 0       New York City Police Department  Noise - Street/Sidewalk
# ...

# %%
data.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2164
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          5914
# Location Type                        131
# Incident Zip                        2615
# Incident Address                   44410
# Street Name                        44410
# Cross Street 1                     49279
# Cross Street 2                     49779
# Intersection Street 1             256840
# Intersection Street 2             257336
# Address Type                        2815
# City                                2614
# Landmark                          300349
# Facility Type                       2171
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2187
# ...

# %%
data.drop(['Intersection Street 1', 'Intersection Street 2','Landmark','School or Citywide Complaint',
       'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
       'Bridge Highway Segment', 'Garage Lot Name', 'Ferry Direction', 'Ferry Terminal Name'], axis='columns', inplace=True)

# %%
data
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 0         32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1         32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2         32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3         32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4         32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
# ...            ...                 ...                 ...    ...
# 300693    30281872 2015-03-29 00:33:41                 NaT   NYPD
# 300694    30281230 2015-03-29 00:33:28 2015-03-29 02:33:59   NYPD
# 300695    30283424 2015-03-29 00:33:03 2015-03-29 03:40:20   NYPD
# 300696    30280004 2015-03-29 00:33:02 2015-03-29 04:38:35   NYPD
# 300697    30281825 2015-03-29 00:33:01 2015-03-29 04:41:50   NYPD
#
#                             Agency Name           Complaint Type  \
# 0       New York City Police Department  Noise - Street/Sidewalk
# ...

# %%
data['Created Date'].min()
# Out:
# Timestamp('2015-03-29 00:33:01')

# %%
data['Created Date'].max()
# Out:
# Timestamp('2015-12-31 23:59:45')

# %%
data['Closed Date'].min()
# Out:
# Timestamp('2015-03-29 00:57:23')

# %%
data['Closed Date'].max()
# Out:
# Timestamp('2016-01-03 16:22:00')

# %%
data['Request_Closing_Time'] = data.groupby(pd.DatetimeIndex(data['Created Date']).month).transform(lambda x: x.fillna(x.mean()))
data['Request_Closing_Time'] = pd.Timedelta(data['Request_Closing_Time'].values)
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-89ea0bfba227> in <module>
#       1 data['Request_Closing_Time'] = data.groupby(pd.DatetimeIndex(data['Created Date']).month).transform(lambda x: x.fillna(x.mean()))
# ----> 2 data['Request_Closing_Time'] = pd.Timedelta(data['Request_Closing_Time'].values)
#       3 data
#
# pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# ValueError: Value must be Timedelta, string, integer, float, timedelta or convertible, not ndarray

# %%
data['Complaint Type'].value_counts()[:10].plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Location Type'].value_counts()[:10].plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Descriptor'].value_counts()[:10].plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Request_Closing_Time'].value_counts()[:5].plot.bar()
# Out:
# <AxesSubplot:>
